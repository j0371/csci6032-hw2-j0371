# %% [markdown]
# # CSCI 6032 Homework 2 AI Usage Notes

# %% [markdown]
# General:</br>
# using Grok Voice Mode to help with various little tech stuff like learning how to create this notebook.
#
# Part 0:</br>
# Using Chatgpt codex in VSC to help generate start batch file and npm dependencies.
#
# Part 3:</br>
# Used ChatGpt to generate the first draft of the agent safety policy. Only minor manual revisions were needed.
#
# Random notes:</br></br>
#
# Part 3:</br>
# To fix the environment issue with the windows update and enabling copilot sandbox, I realized I could just try a completely different environment by pulling the project down on my laptop. I have really ever only had 1 work space before this semester. During undergrad, I only used my main desktop PC, and I only had one work laptop when working at International Paper. The ability to just jump ship on a machine to try it on a completely different environment is a work-around practice that I should keep in mind for the future.</br>
#
# Part 0:</br>
# It's unfortunate that voice mode takes so many more tokens to process now that they're clamping usage limits as these frontier models get more popular. Voice Mode is so much faster and easier to multitask with.
